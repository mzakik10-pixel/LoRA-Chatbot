# %%
# !pip install -q bert_score evaluate

# %%
print("\n" + "="*80)
print("🏆 TABEL KOMPARASI METRIK FINAL (4 MODEL ARSITEKTUR) 🏆")
print("="*80)

# Pastikan skor dialo dan qwen dari run sebelumnya masih di memori.
print("[KANDIDAT 1: DIALOGPT-SMALL] - Baseline Percakapan Kasual")
print(f"  > BERTScore (Akurasi Makna) : {skor_bert_dialo:.4f}")
print(f"  > BLEURT (Preferensi Manusia): {skor_bleurt_dialo:.4f}")
print(f"  > Perplexity (Kefasihan)    : {skor_ppl_dialo:.2f}")
print("-" * 80)

print("[KANDIDAT 2: GPT-NEO-1.3B] - Baseline General Purpose (Klasik)")
print(f"  > BERTScore (Akurasi Makna) : {skor_bert_neo:.4f}")
print(f"  > BLEURT (Preferensi Manusia): {skor_bleurt_neo:.4f}")
print(f"  > Perplexity (Kefasihan)    : {skor_ppl_neo:.2f}")
print("-" * 80)

print("[KANDIDAT 3: TINYLLAMA-1.1B] - Baseline SLM Instruct (Modern)")
print(f"  > BERTScore (Akurasi Makna) : {skor_bert_llama:.4f}")
print(f"  > BLEURT (Preferensi Manusia): {skor_bleurt_llama:.4f}")
print(f"  > Perplexity (Kefasihan)    : {skor_ppl_llama:.2f}")
print("-" * 80)

print("[KANDIDAT 4: QWEN2.5-1.5B LoRA] - Spesialis Fitness (Fine-Tuned)")
print(f"  > BERTScore (Akurasi Makna) : {skor_bert_qwen:.4f}")
print(f"  > BLEURT (Preferensi Manusia): {skor_bleurt_qwen:.4f}")
print(f"  > Perplexity (Kefasihan)    : {skor_ppl_qwen:.2f}")
print("="*80)
